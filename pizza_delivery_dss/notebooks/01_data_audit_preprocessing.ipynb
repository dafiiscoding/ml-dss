# %% [markdown]
# # Module 01 - Data Audit and Preprocessing
#
# Notebook này kiểm tra dữ liệu gốc, chuẩn hóa schema, xác định leakage
# columns và tạo split train/dev/test cố định.

# %% [markdown]
# > **Đối tượng & cách đọc.** Notebook cho **người mới** trong nhóm. Lời
# > giải thích bằng tiếng Việt; thuật ngữ tiếng Anh (F2, MCC, bootstrap…)
# > được định nghĩa ở mục **"0. Định nghĩa"** và đầy đủ trong
# > `docs/GLOSSARY.md`. Mỗi mục theo mạch *mục tiêu → phân tích → insight*;
# > mỗi bảng/biểu đồ có **một dòng đọc-hiểu ngay bên dưới**.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

import pandas as pd
from pizza_dss.business_analysis import dtype_audit, redundant_feature_audit, synthetic_data_audit
from pizza_dss.config import FEATURE_COLUMNS, LEAKAGE_COLUMNS
from pizza_dss.data_loader import (
    audit_dataset,
    export_processed_splits,
    load_dataset,
    validate_feature_contract,
)
from pizza_dss.data_forensics import infer_delay_threshold

# %% [markdown]
# ## Bức tranh tổng (đọc trước khi đi vào chi tiết)
#
# Sơ đồ dưới là toàn bộ luồng dự án, từ dữ liệu thô đến quyết định vận
# hành. Mỗi ô là một notebook. Người mới nên xem hình này trước rồi đi
# lần lượt 01 → 06.

# %%
import sys as _sys
from IPython.display import Image
_sys.path.insert(0, str(PROJECT_ROOT))
from scripts.build_overview_figure import build as _build_overview
Image(filename=str(_build_overview()))
# Out:
# Saved -> C:\Users\doand\Desktop\Workspace\1-Projects\ml-dss\pizza_delivery_dss\reports\figures\pipeline_overview.png

# %% [markdown]
# ## 0. Định nghĩa thuật ngữ tiền xử lý
#
# - **Schema**: tập cột + kiểu dữ liệu. **snake_case**: chuẩn hóa tên cột.
# - **Leakage (rò rỉ)**: dùng thông tin chỉ biết *sau* khi giao hàng làm
#   feature dự báo → kết quả ảo. Ở đây gồm duration/delay/efficiency/
#   restaurant_avg_time vì chúng định nghĩa hoặc suy ra nhãn.
# - **Stratified split**: chia train/dev/test giữ nguyên tỷ lệ trễ ở mỗi
#   phần, để dev/test đại diện đúng cho phân phối nhãn.
# - **Feature contract**: ràng buộc code chặn mọi feature nằm trong danh
#   sách leakage (raise lỗi nếu vi phạm).

# %% [markdown]
# ## 1. Load and schema

# %%
df = load_dataset()
df.shape, df.head()
# Out:
# ((1004, 37),
#    order_id restaurant_name         location          order_time  \
#  0   ORD001        Domino's     New York, NY 2024-01-05 18:30:00
#  1   ORD002     Papa John's  Los Angeles, CA 2024-02-14 20:00:00
#  2   ORD003  Little Caesars      Chicago, IL 2024-03-21 12:15:00
#  3   ORD004       Pizza Hut        Miami, FL 2024-04-10 19:45:00
#  4   ORD005   Marco's Pizza       Dallas, TX 2024-05-05 13:00:00
#
#          delivery_time  delivery_duration_min pizza_size    pizza_type  \
#  0 2024-01-05 18:45:00                     15     Medium           Veg
#  1 2024-02-14 20:25:00                     25      Large       Non-Veg
#  2 2024-03-21 12:35:00                     20      Small         Vegan
#  3 2024-04-10 20:10:00                     25         XL  Cheese Burst
#  4 2024-05-05 13:20:00                     20     Medium       Non-Veg
#
#     toppings_count  distance_km  ... order_month_num pizza_size_score  \
#  0               3          2.5  ...               1                2
#  1               4          5.0  ...               2                3
#  2               2          3.0  ...               3                1
#  3               5          4.5  ...               4                4
#  4               3          2.0  ...               5                2
#
#     pizza_size_code  pizza_size_label  order_period  order_weekday  \
#  0               02         02_Medium       2024-01              4
#  1               03          03_Large       2024-02              2
#  2               01          01_Small       2024-03              3
#  3               04             04_XL       2024-04              2
#  4               02         02_Medium       2024-05              6
#
#    order_weekday_name time_segment  complexity_band  distance_band
#  0             Friday       Dinner           Medium         0-3 km
#  1          Wednesday       Dinner             High         3-6 km
#  2           Thursday        Lunch              Low         0-3 km
#  3          Wednesday       Dinner        Very High         3-6 km
#  4             Sunday        Lunch           Medium         0-3 km
#
#  [5 rows x 37 columns])

# %% [markdown]
# **Vì sao bước này?**
# - Làm gì: Đổi tên cột sang định dạng `snake_case` và sửa lỗi chính tả "Marco’s Pizza" (trong `load_dataset`).
# - Vì sao: Để code dễ đọc, nhất quán theo chuẩn Python, và gộp đúng các nhóm nhà hàng thay vì bị tách lẻ do dấu nháy khác nhau.
# - Kỹ thuật: Renaming & String replacement.
# - Bằng chứng dẫn tới: Dữ liệu thô dùng `Title Case` có khoảng trắng (vd `Order ID`), cản trở truy xuất `df.order_id`.

# %%
dtype_audit(df)
# Out:
#                             column           dtype  missing  nunique  \
# 0                         order_id             str        0     1004
# 1                  restaurant_name             str        0        5
# 2                         location             str        0       84
# 3                       order_time  datetime64[us]        0      968
# 4                    delivery_time  datetime64[us]        0      980
# 5            delivery_duration_min           int64        0        8
# 6                       pizza_size             str        0        4
# 7                       pizza_type             str        0       12
# 8                   toppings_count           int64        0        5
# 9                      distance_km         float64        0       25
# 10                   traffic_level             str        0        3
# 11                  payment_method             str        0        6
# 12                    is_peak_hour            bool        0        2
# 13                      is_weekend            bool        0        2
# 14  delivery_efficiency_min_per_km         float64        0       40
# 15                 topping_density         float64        0       37
# 16                     order_month             str        0       12
# 17                payment_category             str        0        2
# 18          estimated_duration_min         float64        0       25
# 19                       delay_min         float64        0       54
# 20                      is_delayed            bool        0        2
# 21                pizza_complexity           int64        0       10
# 22                  traffic_impact           int64        0        3
# 23                      order_hour           int64        0        8
# 24             restaurant_avg_time         float64        0        6
# 25                      order_date             str        0      847
# 26                      order_year           int32        0        3
# 27                 order_month_num           int32        0       12
# 28                pizza_size_score           int64        0        4
# 29                 pizza_size_code             str        0        4
# 30                pizza_size_label             str        0        4
# 31                    order_period             str        0       31
# 32                   order_weekday           int32        0        7
# 33              order_weekday_name             str        0        7
# 34                    time_segment             str        0        3
# 35                 complexity_band             str        0        4
# 36                   distance_band             str        0        4
#
#                                         sample_values
# 0              ORD001, ORD002, ORD003, ORD004, ORD005
# 1   Domino's, Papa John's, Little Caesars, Pizza H...
# 2   New York, NY, Los Angeles, CA, Chicago, IL, Mi...
# 3   2024-01-05 18:30:00, 2024-02-14 20:00:00, 2024...
# 4   2024-01-05 18:45:00, 2024-02-14 20:25:00, 2024...
# 5                                  15, 25, 20, 30, 40
# 6                            Medium, Large, Small, XL
# 7      Veg, Non-Veg, Vegan, Cheese Burst, Gluten-Free
# 8                                       3, 4, 2, 5, 1
# 9                             2.5, 5.0, 3.0, 4.5, 2.0
# 10                                  Medium, High, Low
# 11             Card, Wallet, UPI, Cash, Domino's Cash
# 12                                        True, False
# 13                                        False, True
# 14  6.0, 5.0, 6.666666666666667, 5.555555555555555...
# 15  1.2, 0.8, 0.6666666666666666, 1.11111111111111...
# 16               January, February, March, April, May
# 17                                    Online, Offline
# 18            6.0, 12.0, 7.199999999999999, 10.8, 4.8
# 19                        9.0, 13.0, 12.8, 14.2, 15.2
# 20                                        False, True
# 21                                    6, 12, 2, 20, 4
# 22                                            2, 3, 1
# 23                                 18, 20, 12, 19, 13
# 24  30.25943396226415, 28.18627450980392, 28.84422...
# 25  2024-01-05, 2024-02-14, 2024-03-21, 2024-04-10...
# 26                                   2024, 2025, 2026
# 27                                      1, 2, 3, 4, 5
# 28                                         2, 3, 1, 4
# 29                                     02, 03, 01, 04
# 30               02_Medium, 03_Large, 01_Small, 04_XL
# 31        2024-01, 2024-02, 2024-03, 2024-04, 2024-05
# 32                                      4, 2, 3, 6, 5
# 33      Friday, Wednesday, Thursday, Sunday, Saturday
# 34                                Dinner, Lunch, Late
# 35                       Medium, High, Low, Very High
# 36                      0-3 km, 3-6 km, 6-8 km, 8+ km

# %% [markdown]
# **Insight (schema).** 1.004 đơn, 37 cột sau FE, không có cột nào sai kiểu rõ rệt; bảng này là tham chiếu kiểu/dtype cho các bước sau.

# %% [markdown]
# ### 1b. Audit lẫn int/float
#
# Dữ liệu trộn kiểu int và float. Cell dưới chỉ ra cột nào *lưu dạng float
# nhưng giá trị thực ra là số nguyên* — dấu hiệu generator sinh số rồi ép
# kiểu, và là lý do ta mã hóa/ép kiểu nhất quán khi xây feature.

# %%
numeric = df.select_dtypes("number")
audit = pd.DataFrame({
    "column": numeric.columns,
    "dtype": [str(numeric[c].dtype) for c in numeric.columns],
    "is_integer_valued": [bool((numeric[c].dropna() % 1 == 0).all()) for c in numeric.columns],
})
audit["stored_as_float_but_integer"] = audit["dtype"].str.startswith("float") & audit["is_integer_valued"]
audit
# Out:
#                             column    dtype  is_integer_valued  \
# 0            delivery_duration_min    int64               True
# 1                   toppings_count    int64               True
# 2                      distance_km  float64              False
# 3   delivery_efficiency_min_per_km  float64              False
# 4                  topping_density  float64              False
# 5           estimated_duration_min  float64              False
# 6                        delay_min  float64              False
# 7                 pizza_complexity    int64               True
# 8                   traffic_impact    int64               True
# 9                       order_hour    int64               True
# 10             restaurant_avg_time  float64              False
# 11                      order_year    int32               True
# 12                 order_month_num    int32               True
# 13                pizza_size_score    int64               True
# 14                   order_weekday    int32               True
#
#     stored_as_float_but_integer
# 0                         False
# 1                         False
# 2                         False
# 3                         False
# 4                         False
# 5                         False
# 6                         False
# 7                         False
# 8                         False
# 9                         False
# 10                        False
# 11                        False
# 12                        False
# 13                        False
# 14                        False

# %% [markdown]
# **Insight (int/float).** Các cột `stored_as_float_but_integer=True` (vd toppings, order_hour) bản chất là số nguyên bị lưu float — vô hại cho mô hình sau khi StandardScaler, nhưng được ghi nhận như một dấu hiệu synthetic.

# %% [markdown]
# ## 2. Feature engineering cho size/time/complexity

# %% [markdown]
# **Vì sao bước này?**
# - Làm gì: Tạo các cột biến đổi (feature engineering) từ dữ liệu gốc, bao gồm `pizza_size_score` (ordinal), `time_segment` (nhóm giờ), `complexity_band`, `distance_band` (khoảng), và `order_period`.
# - Vì sao:
#   - `pizza_size` có thứ tự (Small < Medium < Large < XL) nên dùng Ordinal Encoding (`pizza_size_score` 1..4) giúp mô hình bắt được xu hướng tăng dần. Cột `code` và `label` dùng cho Dashboard hiển thị đẹp.
#   - Nhóm giờ (`time_segment`), độ phức tạp (`complexity_band`), khoảng cách (`distance_band`) giúp giảm nhiễu (noise) và bắt được các pattern gộp (vd: "đơn xa trên 8km") hữu ích cho cây quyết định. Các ngưỡng chia dựa trên phân phối thực tế của dữ liệu.
# - Kỹ thuật: Ordinal Encoding, Binning (pd.cut).
# - Bằng chứng dẫn tới: `pizza_size` mang tính thứ bậc tự nhiên. Các ngưỡng `time_segment` (0,11,15,17,21,24) khớp với các ca hoạt động thực tế (Lunch, Afternoon, Dinner, Late).

# %% [markdown]
# **Vì sao FE `pizza_size_score`?**
# - Làm gì: Ánh xạ Small/Medium/Large/XL thành 1/2/3/4.
# - Vì sao: Size có thứ tự tự nhiên; XL lớn hơn Large, Large lớn hơn Medium.
#   Ordinal score giữ được quan hệ tăng dần để mô hình tuyến tính đọc được.
# - Kỹ thuật: Ordinal encoding.
# - Bằng chứng dẫn tới: `SIZE_SCORE` trong `data_loader.py` và
#   `generator_deterministic_formulas.csv` cho thấy `pizza_complexity =
#   toppings_count * pizza_size_score`, tức generator cũng xem size là
#   thang thứ bậc.

# %% [markdown]
# **Vì sao FE `pizza_size_code` / `pizza_size_label`?**
# - Làm gì: Tạo mã `01`..`04` và nhãn `01_Small`..`04_XL`.
# - Vì sao: Dashboard/notebook cần sort đúng thứ tự size; nếu sort chữ
#   đơn thuần thì Large/Medium/Small/XL dễ bị xếp sai ngữ nghĩa.
# - Kỹ thuật: Label engineering phục vụ báo cáo/BI, không phải feature
#   chính cho model compact.
# - Bằng chứng dẫn tới: `size_mix.csv` và Power BI pack cần hiển thị size
#   theo thứ tự Small → Medium → Large → XL.

# %% [markdown]
# **Vì sao FE `time_segment`?**
# - Làm gì: Gom `order_hour` vào Other/Lunch/Afternoon/Dinner/Late bằng
#   các mốc 0, 11, 15, 17, 21, 24.
# - Vì sao: Điều phối nhân sự thường ra quyết định theo ca, không theo
#   từng giờ rời rạc; dinner peak là ngữ cảnh vận hành quan trọng.
# - Kỹ thuật: Binning bằng `pd.cut`.
# - Bằng chứng dẫn tới: `hourly_staffing_plan.csv` chỉ ra peak hour 19h,
#   nằm trong nhóm Dinner.

# %% [markdown]
# **Vì sao FE `complexity_band` và `distance_band`?**
# - Làm gì: Gom complexity thành Low/Medium/High/Very High và distance
#   thành 0-3/3-6/6-8/8+ km.
# - Vì sao: Band giúp EDA, association rules và dashboard đọc rủi ro theo
#   nhóm vận hành thay vì nhìn số liên tục khó diễn giải.
# - Kỹ thuật: Binning có ngưỡng cố định.
# - Bằng chứng dẫn tới: `delay_rate_by_distance_band.csv` và
#   `delay_rate_by_complexity_band.csv` cho thấy delay rate thay đổi theo
#   các dải này; `risk_calibration.csv` dùng cùng tư duy band để kiểm tra
#   Risk Score.

# %% [markdown]
# **Vì sao FE `order_period` / `order_weekday`?**
# - Làm gì: Tách tháng dạng `YYYY-MM`, thứ trong tuần dạng số và tên ngày.
# - Vì sao: Forecast cần chuỗi theo tháng; customer behavior và staffing
#   cần biết weekday/weekend hoặc ngày trong tuần.
# - Kỹ thuật: Datetime feature extraction.
# - Bằng chứng dẫn tới: `monthly_demand_forecast.csv`,
#   `preference_trend_forecast.csv` và `hourly_staffing_plan.csv` đều cần
#   feature thời gian đã chuẩn hóa.

# %%
df[[
    "pizza_size", "pizza_size_score", "pizza_size_code", "pizza_size_label",
    "time_segment", "complexity_band", "distance_band", "order_period",
    "order_weekday", "order_weekday_name"
]].head()
# Out:
#   pizza_size  pizza_size_score pizza_size_code pizza_size_label time_segment  \
# 0     Medium                 2              02        02_Medium       Dinner
# 1      Large                 3              03         03_Large       Dinner
# 2      Small                 1              01         01_Small        Lunch
# 3         XL                 4              04            04_XL       Dinner
# 4     Medium                 2              02        02_Medium        Lunch
#
#   complexity_band distance_band order_period  order_weekday order_weekday_name
# 0          Medium        0-3 km      2024-01              4             Friday
# 1            High        3-6 km      2024-02              2          Wednesday
# 2             Low        0-3 km      2024-03              3           Thursday
# 3       Very High        3-6 km      2024-04              2          Wednesday
# 4          Medium        0-3 km      2024-05              6             Sunday

# %%
df.groupby(["pizza_size_score", "pizza_size_label"]).size().reset_index(name="orders")
# Out:
#    pizza_size_score pizza_size_label  orders
# 0                 1         01_Small     132
# 1                 2        02_Medium     429
# 2                 3         03_Large     240
# 3                 4            04_XL     203

# %% [markdown]
# ## 3. Leakage and synthetic-data audit

# %% [markdown]
# **Vì sao bước này?**
# - Làm gì: Phát hiện và loại bỏ các cột Leakage (rò rỉ tương lai) và các cột Redundant (dư thừa, công thức tất định).
# - Vì sao:
#   - Cột **Leakage** (`delivery_duration_min`, `delay_min`, `delivery_efficiency_min_per_km`, `restaurant_avg_time`, `delivery_time`) chứa thông tin chỉ có *sau khi* giao xong. Dùng chúng mô hình sẽ "học vẹt" đáp án, accuracy 100% khi train nhưng vô dụng khi chạy thực tế (lúc vừa nhận đơn chưa có thời gian giao).
#   - Cột **Redundant** (`estimated_duration_min`, `topping_density`, `pizza_complexity`, `traffic_impact`) bị loại trong tập feature gọn (`COMPACT_FEATURE_COLUMNS`) để tránh đa cộng tuyến.
# - Kỹ thuật: Feature Selection (Leakage detection, Deterministic formula discovery).
# - Bằng chứng dẫn tới: `redundant_feature_audit.csv` và `generator_deterministic_formulas.csv` cho thấy sai số max_abs_error ≈ 0 khi phục hồi công thức. Nghĩa là chúng được tính toán trực tiếp từ các cột khác.

# %% [markdown]
# **Vì sao cấm từng leakage column?**
# - Làm gì: Chặn 5 cột hậu nghiệm khỏi `FEATURE_COLUMNS`.
# - Vì sao: Khi đơn vừa được đặt, hệ thống chưa biết thời gian giao thật,
#   thời gian kết thúc, hay thống kê trung bình tính từ kết quả giao.
# - Kỹ thuật: Leakage audit + feature contract.
# - Bằng chứng dẫn tới:
#   `delivery_duration_min` phục dựng nhãn với mismatch 0;
#   `delay_min = delivery_duration_min - estimated_duration_min`;
#   `delivery_efficiency_min_per_km = delivery_duration_min / distance_km`;
#   `restaurant_avg_time` là thống kê hậu nghiệm theo nhà hàng;
#   `delivery_time` chỉ có sau khi giao xong. Các quan hệ này nằm trong
#   `data_quality_summary.json`, `redundant_feature_audit.csv` và
#   `generator_deterministic_formulas.csv`.

# %%
pd.DataFrame([
    {"column": "delivery_duration_min", "why_blocked": "Actual duration after delivery; reconstructs is_delayed with 0 mismatch."},
    {"column": "delay_min", "why_blocked": "Formula from actual duration minus estimated duration."},
    {"column": "delivery_efficiency_min_per_km", "why_blocked": "Formula from actual duration divided by distance."},
    {"column": "restaurant_avg_time", "why_blocked": "Post-hoc restaurant aggregate derived from delivery outcomes."},
    {"column": "delivery_time", "why_blocked": "Timestamp known only after the order has been delivered."},
])
# Out:
#                            column  \
# 0           delivery_duration_min
# 1                       delay_min
# 2  delivery_efficiency_min_per_km
# 3             restaurant_avg_time
# 4                   delivery_time
#
#                                          why_blocked
# 0  Actual duration after delivery; reconstructs i...
# 1  Formula from actual duration minus estimated d...
# 2  Formula from actual duration divided by distance.
# 3  Post-hoc restaurant aggregate derived from del...
# 4  Timestamp known only after the order has been ...

# %% [markdown]
# **Vì sao bỏ cột deterministic khỏi compact model?**
# - Làm gì: Compact feature set giữ biến gốc và bỏ các biến công thức như
#   `estimated_duration_min`, `topping_density`, `pizza_complexity`,
#   `traffic_impact`.
# - Vì sao: Các cột này không thêm thông tin mới; giữ lại dễ làm mô hình
#   phụ thuộc vào bản sao của cùng tín hiệu và khó giải thích hơn.
# - Kỹ thuật: Redundant feature removal.
# - Bằng chứng dẫn tới: `redundant_feature_audit.csv` ghi max_abs_error
#   xấp xỉ 0 cho các công thức; `feature_set_comparison.csv` cho thấy
#   compact vẫn đạt F2 ngang hoặc tốt hơn full.

# %%
audit_dataset(df)
# Out:
# {'rows': 1004,
#  'columns': 37,
#  'missing_total': 0,
#  'duplicate_order_ids': 0,
#  'date_min': '2024-01-05 18:30:00',
#  'date_max': '2026-07-07 20:00:00',
#  'years': {'2024': 443, '2025': 373, '2026': 188},
#  'target_distribution': {'False': 794, 'True': 210},
#  'delayed_rate': 0.2092,
#  'is_delayed_equals_duration_gt_30': True,
#  'max_delay_formula_error': 0.0,
#  'chronological_last20_rows': 201,
#  'chronological_last20_delayed': 0,
#  'feature_columns': ['toppings_count',
#   'distance_km',
#   'topping_density',
#   'estimated_duration_min',
#   'pizza_complexity',
#   'traffic_impact',
#   'order_hour',
#   'restaurant_name',
#   'location',
#   'pizza_size',
#   'pizza_type',
#   'traffic_level',
#   'payment_method',
#   'is_peak_hour',
#   'is_weekend',
#   'order_month',
#   'payment_category'],
#  'blocked_leakage_columns': ['delivery_time',
#   'delivery_duration_min',
#   'delivery_efficiency_min_per_km',
#   'delay_min',
#   'restaurant_avg_time']}

# %% [markdown]
# `is_delayed` là nhãn có sẵn trong file, nhưng file không giải thích
# SLA bao nhiêu phút thì trễ. Vì vậy ta suy luận ranh giới nhãn bằng
# cách thử các luật ngưỡng trên `delivery_duration_min` và đếm số dòng
# mismatch.

# %%
infer_delay_threshold(df).head(8)
# Out:
#                           rule operator  threshold_minutes  mismatches  \
# 0   delivery_duration_min > 30        >               30.0           0
# 1  delivery_duration_min >= 35       >=               35.0           0
# 2   delivery_duration_min > 35        >               35.0          44
# 3  delivery_duration_min >= 40       >=               40.0          44
# 4   delivery_duration_min > 40        >               40.0         136
# 5  delivery_duration_min >= 45       >=               45.0         136
# 6   delivery_duration_min > 45        >               45.0         170
# 7  delivery_duration_min >= 50       >=               50.0         170
#
#    mismatch_rate  accuracy  false_positives  false_negatives  \
# 0       0.000000  1.000000                0                0
# 1       0.000000  1.000000                0                0
# 2       0.043825  0.956175                0               44
# 3       0.043825  0.956175                0               44
# 4       0.135458  0.864542                0              136
# 5       0.135458  0.864542                0              136
# 6       0.169323  0.830677                0              170
# 7       0.169323  0.830677                0              170
#
#    predicted_delayed  actual_delayed  exact_match  \
# 0                210             210         True
# 1                210             210         True
# 2                166             210        False
# 3                166             210        False
# 4                 74             210        False
# 5                 74             210        False
# 6                 40             210        False
# 7                 40             210        False
#
#    max_observed_on_time_duration  min_observed_delayed_duration  \
# 0                           30.0                           35.0
# 1                           30.0                           35.0
# 2                           30.0                           35.0
# 3                           30.0                           35.0
# 4                           30.0                           35.0
# 5                           30.0                           35.0
# 6                           30.0                           35.0
# 7                           30.0                           35.0
#
#                                       interpretation
# 0  Observationally exact on this 5-minute duratio...
# 1  Observationally exact on this 5-minute duratio...
# 2     Does not reproduce the provided label exactly.
# 3     Does not reproduce the provided label exactly.
# 4     Does not reproduce the provided label exactly.
# 5     Does not reproduce the provided label exactly.
# 6     Does not reproduce the provided label exactly.
# 7     Does not reproduce the provided label exactly.

# %%
synthetic_data_audit(df)
# Out:
#                                             check  severity  \
# 0                               No missing values   warning
# 1      Future timestamp relative to analysis date   warning
# 2   Label is deterministic from delivery duration  critical
# 3                      Estimated duration formula   warning
# 4                         Topping density formula   warning
# 5                        Pizza complexity formula   warning
# 6    Traffic impact is only encoded traffic level   warning
# 7       Delivery duration has few discrete values   warning
# 8                    Order hour support is narrow   warning
# 9                 Distance support is discretized   warning
# 10               Toppings count support is narrow   warning
# 11        Restaurant distribution is near uniform      info
# 12                           Sequential order ids      info
# 13                             Repeated time gaps   warning
# 14                          Starts after New Year      info
#
#                                              evidence  \
# 0                   0 missing cells across 37 columns
# 1   max order_time=2026-07-07 20:00:00, analysis_d...
# 2                                                True
# 3   max |estimated_duration_min - 2.4 * distance_k...
# 4   max |topping_density - toppings_count / distan...
# 5   max |pizza_complexity - toppings_count * size_...
# 6              unique traffic_impact values=[1, 2, 3]
# 7   8 unique values: [15, 20, 25, 30, 35, 40, 45, 50]
# 8                    8 unique hours; 94.2% are 18-20h
# 9                25 unique distances across 1004 rows
# 10                   1:43, 2:198, 3:319, 4:240, 5:204
# 11                   min=194, max=212 across 5 brands
# 12                     missing ids inside ORD range=1
# 13           top gap=1 days 01:15:00 occurs 269 times
# 14                 min order_time=2024-01-05 18:30:00
#
#                                        interpretation
# 0   Clean data is useful, but a zero-missing opera...
# 1   The file title says 2024-25, but rows reach Ju...
# 2   delivery_duration_min, delay_min and delivery_...
# 3   estimated_duration_min is a deterministic tran...
# 4   topping_density duplicates information already...
# 5   pizza_complexity is engineered from toppings_c...
# 6     traffic_impact is redundant with traffic_level.
# 7   Real delivery duration usually has richer minu...
# 8   This is useful for dinner-peak staffing but to...
# 9   Distances look sampled from a short menu of va...
# 10  Toppings are limited to 1-5, with most rows be...
# 11  Uniform brand counts often appear in generated...
# 12  Sequential ids are acceptable, but they reinfo...
# 13  Order timestamps progress with repeated gaps r...
# 14  The 2024 series starts on Jan 5; without busin...

# %%
redundant_feature_audit(df)
# Out:
#                            column  \
# 0          estimated_duration_min
# 1                 topping_density
# 2                pizza_complexity
# 3                  traffic_impact
# 4                       delay_min
# 5  delivery_efficiency_min_per_km
# 6             restaurant_avg_time
#
#                                 source_or_formula  max_abs_error  \
# 0                               2.4 * distance_km   3.552714e-15
# 1                    toppings_count / distance_km   2.220446e-16
# 2               toppings_count * pizza_size_score   0.000000e+00
# 3                         Low=1, Medium=2, High=3   0.000000e+00
# 4  delivery_duration_min - estimated_duration_min   3.552714e-15
# 5             delivery_duration_min / distance_km   0.000000e+00
# 6          group statistic from delivery duration            NaN
#
#                                         model_action
# 0     Drop in compact feature set; keep distance_km.
# 1  Drop in compact feature set; keep base variables.
# 2  Use for interpretation; compact model uses siz...
# 3   Drop in compact feature set; keep traffic_level.
# 4                                  Block as leakage.
# 5                                  Block as leakage.
# 6               Block as post-hoc aggregate leakage.

# %%
{
    "feature_columns": FEATURE_COLUMNS,
    "blocked_leakage_columns": LEAKAGE_COLUMNS,
    "feature_contract_passed": validate_feature_contract(),
}
# Out:
# {'feature_columns': ['toppings_count',
#   'distance_km',
#   'topping_density',
#   'estimated_duration_min',
#   'pizza_complexity',
#   'traffic_impact',
#   'order_hour',
#   'restaurant_name',
#   'location',
#   'pizza_size',
#   'pizza_type',
#   'traffic_level',
#   'payment_method',
#   'is_peak_hour',
#   'is_weekend',
#   'order_month',
#   'payment_category'],
#  'blocked_leakage_columns': ['delivery_time',
#   'delivery_duration_min',
#   'delivery_efficiency_min_per_km',
#   'delay_min',
#   'restaurant_avg_time'],
#  'feature_contract_passed': True}

# %% [markdown]
# ## 3b. Hình minh hoạ dữ liệu và ranh giới nhãn
#
# **Lý do.** Hai biểu đồ dưới cho thấy lớp trễ là thiểu số và nhãn nằm
# đúng trên lưới 5 phút: nhóm on-time tối đa 30 phút, nhóm delayed tối
# thiểu 35 phút.

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(11, 4))
df["is_delayed"].value_counts().rename({False: "On-time", True: "Delayed"}).plot.bar(
    ax=axes[0], color=["#27ae60", "#c0392b"]
)
axes[0].set_title("Class balance (is_delayed)")
axes[0].set_ylabel("Orders")
axes[0].tick_params(axis="x", rotation=0)
for label, group in df.groupby("is_delayed"):
    axes[1].hist(
        group["delivery_duration_min"],
        bins=range(13, 56, 5),
        alpha=0.6,
        label=("Delayed" if label else "On-time"),
    )
axes[1].axvspan(30, 35, color="grey", alpha=0.25, label="inferred boundary")
axes[1].set_title("Delivery duration by label")
axes[1].set_xlabel("Delivery duration (min)")
axes[1].set_ylabel("Orders")
axes[1].legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# **Insight.** Tỷ lệ trễ ~21% nên Accuracy đơn lẻ sẽ đánh lừa; cần F2/
# Recall cùng Balanced Accuracy/MCC. Ranh giới nhãn là suy luận từ dữ
# liệu, củng cố quyết định chặn duration/delay khỏi feature.

# %% [markdown]
# ## 4. Processed splits

# %% [markdown]
# **Vì sao bước này?**
# - Làm gì: Chia tập dữ liệu thành Train/Dev/Test theo tỷ lệ 60/20/20 bằng phương pháp Stratified (giữ nguyên tỷ lệ nhãn `is_delayed` trong từng tập).
# - Vì sao: Để đảm bảo mọi tập dữ liệu đều có tỷ lệ trễ ~21%. Nếu chia theo thời gian (chronological split), phần đuôi (last-20%) hoàn toàn không có đơn bị trễ, khiến tập Test trở nên vô nghĩa không thể đánh giá khả năng bắt lỗi trễ.
# - Kỹ thuật: Stratified Split.
# - Bằng chứng dẫn tới: Báo cáo `data_quality_summary.json` ghi nhận `chronological_last20_delayed = 0`, chứng tỏ dữ liệu mất cân bằng theo trục thời gian ở đoạn cuối.

# %%
export_processed_splits()
# Out:
# {'train': 602, 'dev': 201, 'test': 201}

# %%
splits = {
    name: pd.read_csv(PROJECT_ROOT / "data" / "processed" / f"{name}.csv")
    for name in ["train", "dev", "test"]
}
pd.DataFrame([
    {
        "split": name,
        "rows": len(frame),
        "delayed": int(frame["is_delayed"].sum()),
        "delayed_rate": frame["is_delayed"].mean(),
    }
    for name, frame in splits.items()
])
# Out:
#    split  rows  delayed  delayed_rate
# 0  train   602      126      0.209302
# 1    dev   201       42      0.208955
# 2   test   201       42      0.208955

# %% [markdown]
# ### 4b. Kiểm tra split không rò rỉ
#
# Hai điều phải đúng: (1) không `order_id` nào xuất hiện ở hơn một split;
# (2) tỷ lệ trễ được giữ gần như nhau giữa các split (stratify).

# %%
ids = {name: set(frame["order_id"]) for name, frame in splits.items()}
overlaps = {
    "train∩dev": len(ids["train"] & ids["dev"]),
    "train∩test": len(ids["train"] & ids["test"]),
    "dev∩test": len(ids["dev"] & ids["test"]),
}
pd.DataFrame([
    {"check": "row_id_overlaps_between_splits", **overlaps},
])
# Out:
#                             check  train∩dev  train∩test  dev∩test
# 0  row_id_overlaps_between_splits          0           0         0

# %% [markdown]
# **Insight (rò rỉ split).** Mọi giao tập `order_id` = 0 → không đơn nào lọt sang split khác; cùng với tỷ lệ trễ ~21% giữ đều (bảng mục 4), split là leakage-safe và đại diện.

# %% [markdown]
# ## 5. Insight → quyết định tiền xử lý

# %%
pd.DataFrame([
    {
        "question": "Có missing/duplicate không?",
        "evidence": "missing_total=0, duplicate_order_ids=0 trong audit_dataset.",
        "decision": "Không cần imputation; nhưng zero-missing là dấu hiệu synthetic, ghi vào audit.",
    },
    {
        "question": "Nhãn is_delayed định nghĩa thế nào?",
        "evidence": "is_delayed == (delivery_duration_min > 30), mismatch=0.",
        "decision": "Chặn duration/delay/efficiency/restaurant_avg_time khỏi feature.",
    },
    {
        "question": "Cột nào trùng thông tin?",
        "evidence": "estimated_duration=2.4*distance; complexity=toppings*size; density=toppings/distance.",
        "decision": "Dùng compact feature set, bỏ cột công thức, giữ pizza_size_score.",
    },
    {
        "question": "Split thế nào?",
        "evidence": "Chronological last-20% có 0 delayed.",
        "decision": "Dùng stratified train/dev/test 602/201/201, ghi rõ giới hạn.",
    },
])
# Out:
#                               question  \
# 0          Có missing/duplicate không?
# 1  Nhãn is_delayed định nghĩa thế nào?
# 2             Cột nào trùng thông tin?
# 3                       Split thế nào?
#
#                                             evidence  \
# 0  missing_total=0, duplicate_order_ids=0 trong a...
# 1  is_delayed == (delivery_duration_min > 30), mi...
# 2  estimated_duration=2.4*distance; complexity=to...
# 3               Chronological last-20% có 0 delayed.
#
#                                             decision
# 0  Không cần imputation; nhưng zero-missing là dấ...
# 1  Chặn duration/delay/efficiency/restaurant_avg_...
# 2  Dùng compact feature set, bỏ cột công thức, gi...
# 3  Dùng stratified train/dev/test 602/201/201, gh...

# %% [markdown]
# Kết luận: dataset gốc đủ nhỏ để xử lý offline bằng pandas/scikit-learn.
# Pipeline giữ raw Excel trong thư mục dự án con và sinh processed CSV
# để notebook, dashboard và PowerBI dùng chung.
