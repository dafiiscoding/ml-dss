# %% [markdown]
# # Module 05 - Customer Behavior, Demand Forecasting, and Recommendation
#
# Notebook này mở rộng phần phân tích dữ liệu rác/synthetic thành nội
# dung học thuật: audit tính giả lập, kiểm định giả thiết, xu hướng
# nhu cầu, staffing theo giờ, preference size/type/restaurant/location,
# recommendation rule và sales-volume reporting.

# %% [markdown]
# > **Đối tượng & cách đọc.** Notebook cho **người mới** trong nhóm. Lời
# > giải thích bằng tiếng Việt; thuật ngữ tiếng Anh (F2, MCC, bootstrap…)
# > được định nghĩa ở mục **"0. Định nghĩa"** và đầy đủ trong
# > `docs/GLOSSARY.md`. Mỗi mục theo mạch *mục tiêu → phân tích → insight*;
# > mỗi bảng/biểu đồ có **một dòng đọc-hiểu ngay bên dưới**.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

import pandas as pd
from pizza_dss.business_analysis import (
    build_business_artifacts,
    customer_preference_tables,
    forecast_method_comparison,
    forecast_metrics,
    forecast_monthly_demand,
    hourly_staffing_plan,
    hypothesis_tests,
    monthly_demand,
    monthly_product_trends,
    preference_trend_tests,
    recommendation_rules,
    redundant_feature_audit,
    synthetic_data_audit,
)
from pizza_dss.data_loader import load_dataset
from IPython.display import Image

# %% [markdown]
# Sinh trước hình business để hiển thị inline.

# %%
_ = build_business_artifacts()

# %% [markdown]
# ## 0. Định nghĩa thuật ngữ business
#
# - **MAE**: sai số tuyệt đối trung bình (đơn vị: số đơn). **MAPE**: sai
#   số phần trăm tuyệt đối trung bình; >40% = forecast yếu.
# - **Seasonal-naive**: dự báo tháng t bằng giá trị cùng kỳ năm trước.
#   **Moving average**: trung bình vài tháng gần nhất.
# - **Mann-Kendall**: kiểm định xu hướng phi tham số; `tau` là cường độ xu
#   hướng, `p < 0.05` mới kết luận có trend (tăng/giảm).
# - **Confidence/Support** của recommendation rule: P(gợi ý | bối cảnh) và
#   tần suất bối cảnh.
# - **order_share**: tỷ trọng đơn của một size/type trên tổng.

# %% [markdown]
# ## 1. Data realism / synthetic audit

# %%
df = load_dataset()
synthetic_data_audit(df)
# Out:
#                                             check  severity  \
# 0                               No missing values   warning
# 1      Future timestamp relative to analysis date   warning
# 2   Label is deterministic from delivery duration  critical
# 3                      Estimated duration formula   warning
# 4                         Topping density formula   warning
# 5                        Pizza complexity formula   warning
# 6    Traffic impact is only encoded traffic level   warning
# 7       Delivery duration has few discrete values   warning
# 8                    Order hour support is narrow   warning
# 9                 Distance support is discretized   warning
# 10               Toppings count support is narrow   warning
# 11        Restaurant distribution is near uniform      info
# 12                           Sequential order ids      info
# 13                             Repeated time gaps   warning
# 14                          Starts after New Year      info
#
#                                              evidence  \
# 0                   0 missing cells across 37 columns
# 1   max order_time=2026-07-07 20:00:00, analysis_d...
# 2                                                True
# 3   max |estimated_duration_min - 2.4 * distance_k...
# 4   max |topping_density - toppings_count / distan...
# 5   max |pizza_complexity - toppings_count * size_...
# 6              unique traffic_impact values=[1, 2, 3]
# 7   8 unique values: [15, 20, 25, 30, 35, 40, 45, 50]
# 8                    8 unique hours; 94.2% are 18-20h
# 9                25 unique distances across 1004 rows
# 10                   1:43, 2:198, 3:319, 4:240, 5:204
# 11                   min=194, max=212 across 5 brands
# 12                     missing ids inside ORD range=1
# 13           top gap=1 days 01:15:00 occurs 269 times
# 14                 min order_time=2024-01-05 18:30:00
#
#                                        interpretation
# 0   Clean data is useful, but a zero-missing opera...
# 1   The file title says 2024-25, but rows reach Ju...
# 2   delivery_duration_min, delay_min and delivery_...
# 3   estimated_duration_min is a deterministic tran...
# 4   topping_density duplicates information already...
# 5   pizza_complexity is engineered from toppings_c...
# 6     traffic_impact is redundant with traffic_level.
# 7   Real delivery duration usually has richer minu...
# 8   This is useful for dinner-peak staffing but to...
# 9   Distances look sampled from a short menu of va...
# 10  Toppings are limited to 1-5, with most rows be...
# 11  Uniform brand counts often appear in generated...
# 12  Sequential ids are acceptable, but they reinfo...
# 13  Order timestamps progress with repeated gaps r...
# 14  The 2024 series starts on Jan 5; without busin...

# %%
redundant_feature_audit(df)
# Out:
#                            column  \
# 0          estimated_duration_min
# 1                 topping_density
# 2                pizza_complexity
# 3                  traffic_impact
# 4                       delay_min
# 5  delivery_efficiency_min_per_km
# 6             restaurant_avg_time
#
#                                 source_or_formula  max_abs_error  \
# 0                               2.4 * distance_km   3.552714e-15
# 1                    toppings_count / distance_km   2.220446e-16
# 2               toppings_count * pizza_size_score   0.000000e+00
# 3                         Low=1, Medium=2, High=3   0.000000e+00
# 4  delivery_duration_min - estimated_duration_min   3.552714e-15
# 5             delivery_duration_min / distance_km   0.000000e+00
# 6          group statistic from delivery duration            NaN
#
#                                         model_action
# 0     Drop in compact feature set; keep distance_km.
# 1  Drop in compact feature set; keep base variables.
# 2  Use for interpretation; compact model uses siz...
# 3   Drop in compact feature set; keep traffic_level.
# 4                                  Block as leakage.
# 5                                  Block as leakage.
# 6               Block as post-hoc aggregate leakage.

# %% [markdown]
# Kết luận: dữ liệu có nhiều cột deterministic. Vì vậy dự án không cố
# che điểm yếu này mà đưa nó vào audit, đồng thời tạo feature set
# compact để so sánh với feature set đầy đủ.

# %%
Image(filename=str(PROJECT_ROOT / "reports" / "figures" / "synthetic_data_flags.png"))

# %%
Image(filename=str(PROJECT_ROOT / "reports" / "figures" / "complexity_distribution.png"))

# %% [markdown]
# ## 2. Hypothesis tests

# %%
hypothesis_tests(df)
# Out:
#            variable                                   test  rows        chi2  \
# 4     traffic_level  chi-square independence vs is_delayed     3  265.676749
# 3        pizza_type  chi-square independence vs is_delayed    12  186.022262
# 0    payment_method  chi-square independence vs is_delayed     6  176.028340
# 8   complexity_band  chi-square independence vs is_delayed     4  151.234790
# 2        pizza_size  chi-square independence vs is_delayed     4  148.199282
# 6    location_top12  chi-square independence vs is_delayed    13  142.016354
# 5   restaurant_name  chi-square independence vs is_delayed     5   18.187573
# 7      time_segment  chi-square independence vs is_delayed     3   14.442731
# 1  payment_category  chi-square independence vs is_delayed     2    0.947863
#
#    dof       p_value  cramers_v  min_expected  significant_at_0_05  \
# 4    2  2.037168e-58   0.514411     58.147410                 True
# 3   11  5.842823e-34   0.430443      0.418327                 True
# 0    5  3.771418e-36   0.418721      4.810757                 True
# 8    3  1.426896e-32   0.388114     42.669323                 True
# 2    3  6.444649e-32   0.384199     27.609562                 True
# 6   12  2.344926e-24   0.376099      7.739044                 True
# 5    4  1.134156e-03   0.134592     40.577689                 True
# 7    2  7.308037e-04   0.119938      0.627490                 True
# 1    1  3.302639e-01   0.030726     52.081673                False
#
#                                  interpretation
# 4            Evidence of association with delay
# 3            Evidence of association with delay
# 0            Evidence of association with delay
# 8            Evidence of association with delay
# 2            Evidence of association with delay
# 6            Evidence of association with delay
# 5            Evidence of association with delay
# 7            Evidence of association with delay
# 1  No strong evidence of association with delay

# %% [markdown]
# Kiểm định chi-square trả lời các câu hỏi kiểu: payment method,
# pizza size, traffic, restaurant, location top-12 có độc lập với
# trạng thái delayed hay không. Với dữ liệu synthetic, p-value chỉ là
# minh chứng phân tích, không được diễn giải như bằng chứng nhân quả.

# %% [markdown]
# ## 3. Customer preferences

# %%
prefs = customer_preference_tables(df)
prefs["size_mix"]
# Out:
#    pizza_size_score pizza_size_label pizza_size  count  delayed  delay_rate  \
# 0                 1         01_Small      Small    132        2    0.015152
# 1                 2        02_Medium     Medium    429       39    0.090909
# 2                 3         03_Large      Large    240       85    0.354167
# 3                 4            04_XL         XL    203       84    0.413793
#
#    order_share
# 0     0.131474
# 1     0.427291
# 2     0.239044
# 3     0.202191

# %%
prefs["type_mix"].head(12)
# Out:
#        pizza_type  count  delayed  delay_rate  order_share
# 5         Non-Veg    216       45    0.208333     0.215139
# 10            Veg    202       44    0.217822     0.201195
# 1    Cheese Burst    188       67    0.356383     0.187251
# 11          Vegan    132        3    0.022727     0.131474
# 6        Sicilian     64        6    0.093750     0.063745
# 4       Margarita     54        0    0.000000     0.053785
# 0     BBQ Chicken     54        0    0.000000     0.053785
# 3     Gluten-Free     41       22    0.536585     0.040837
# 8    Thai Chicken     24        3    0.125000     0.023904
# 7   Stuffed Crust     21       20    0.952381     0.020916
# 2       Deep Dish      6        0    0.000000     0.005976
# 9      Thin Crust      2        0    0.000000     0.001992

# %%
prefs["top_restaurant_by_type"]
# Out:
#        pizza_type restaurant_name  orders  share_within_type
# 25            Veg        Domino's     106           0.524752
# 2    Cheese Burst  Little Caesars      93           0.494681
# 12        Non-Veg   Marco's Pizza      88           0.407407
# 15       Sicilian        Domino's      59           0.921875
# 0     BBQ Chicken     Papa John's      54           1.000000
# 9       Margarita   Marco's Pizza      54           1.000000
# 32          Vegan     Papa John's      47           0.356061
# 8     Gluten-Free     Papa John's      37           0.902439
# 23   Thai Chicken   Marco's Pizza      20           0.833333
# 19  Stuffed Crust  Little Caesars      13           0.619048
# 6       Deep Dish     Papa John's       4           0.666667
# 24     Thin Crust        Domino's       2           1.000000

# %%
prefs["location_summary"].head(15)
# Out:
#            location  orders  delayed  delay_rate  avg_distance_km  \
# 4       Atlanta, GA      78        4    0.051282         4.015385
# 49    Milwaukee, WI      71        3    0.042254         4.577465
# 43   Louisville, KY      69        2    0.028986         5.978261
# 58        Omaha, NE      68        2    0.029412         5.029412
# 1   Albuquerque, NM      59        2    0.033898         5.491525
# 11       Boston, MA      51       17    0.333333         4.843137
# 19       Dallas, TX      50        4    0.080000         3.930000
# 48        Miami, FL      49       12    0.244898         4.495918
# 20       Denver, CO      46        8    0.173913         3.902174
# 14      Chicago, IL      45        3    0.066667         4.355556
# 42  Los Angeles, CA      42       13    0.309524         5.578571
# 73      Seattle, WA      37       11    0.297297         5.443243
# 61      Phoenix, AZ      35       11    0.314286         5.385714
# 31      Houston, TX      27        3    0.111111         3.537037
# 53     New York, NY      21        4    0.190476         4.452381
#
#         top_type top_size
# 4            Veg   Medium
# 49     Margarita   Medium
# 43  Cheese Burst       XL
# 58   BBQ Chicken   Medium
# 1       Sicilian    Large
# 11       Non-Veg    Small
# 19       Non-Veg   Medium
# 48           Veg   Medium
# 20         Vegan    Small
# 14       Non-Veg   Medium
# 42  Cheese Burst       XL
# 73       Non-Veg   Medium
# 61       Non-Veg   Medium
# 31         Vegan    Small
# 53           Veg    Large

# %%
Image(filename=str(PROJECT_ROOT / "reports" / "figures" / "size_preference.png"))

# %% [markdown]
# ## 4. Time series demand and staffing

# %%
monthly_demand(df).tail(15)
# Out:
#    order_period  orders  delayed  delay_rate  avg_distance_km month_start  \
# 16      2025-05      31       17    0.548387         5.693548  2025-05-01
# 17      2025-06      50       26    0.520000         5.654000  2025-06-01
# 18      2025-07      11        6    0.545455         5.590909  2025-07-01
# 19      2025-08      31       12    0.387097         5.129032  2025-08-01
# 20      2025-09      30        2    0.066667         5.100000  2025-09-01
# 21      2025-10      31        0    0.000000         5.032258  2025-10-01
# 22      2025-11      30        0    0.000000         5.000000  2025-11-01
# 23      2025-12      39        0    0.000000         5.038462  2025-12-01
# 24      2026-01      31        0    0.000000         5.000000  2026-01-01
# 25      2026-02      28        0    0.000000         5.017857  2026-02-01
# 26      2026-03      31        0    0.000000         5.048387  2026-03-01
# 27      2026-04      30        0    0.000000         4.983333  2026-04-01
# 28      2026-05      31        0    0.000000         5.048387  2026-05-01
# 29      2026-06      30        0    0.000000         4.983333  2026-06-01
# 30      2026-07       7        0    0.000000         5.071429  2026-07-01
#
#     is_partial_month
# 16             False
# 17             False
# 18             False
# 19             False
# 20             False
# 21             False
# 22             False
# 23             False
# 24             False
# 25             False
# 26             False
# 27             False
# 28             False
# 29             False
# 30              True

# %%
forecast = forecast_monthly_demand(df, horizon=6)
forecast.tail(12)
# Out:
#    order_period month_start  actual_orders  forecast_orders     split  \
# 25      2026-02  2026-02-01           28.0             28.0  backtest
# 26      2026-03  2026-03-01           31.0             31.0  backtest
# 27      2026-04  2026-04-01           30.0             30.0  backtest
# 28      2026-05  2026-05-01           31.0             31.0  backtest
# 29      2026-06  2026-06-01           30.0             50.0  backtest
# 30      2026-07  2026-07-01            7.0             11.0  backtest
# 31      2026-08  2026-08-01            NaN             31.0    future
# 32      2026-09  2026-09-01            NaN             30.0    future
# 33      2026-10  2026-10-01            NaN             31.0    future
# 34      2026-11  2026-11-01            NaN             30.0    future
# 35      2026-12  2026-12-01            NaN             39.0    future
# 36      2027-01  2027-01-01            NaN             31.0    future
#
#                        method  is_partial_month
# 25  seasonal_naive_prior_year             False
# 26  seasonal_naive_prior_year             False
# 27  seasonal_naive_prior_year             False
# 28  seasonal_naive_prior_year             False
# 29  seasonal_naive_prior_year             False
# 30  seasonal_naive_prior_year              True
# 31  seasonal_naive_prior_year             False
# 32  seasonal_naive_prior_year             False
# 33  seasonal_naive_prior_year             False
# 34  seasonal_naive_prior_year             False
# 35  seasonal_naive_prior_year             False
# 36  seasonal_naive_prior_year             False

# %%
forecast_metrics(forecast)
# Out:
# {'backtest_rows': 19,
#  'mae': 12.211,
#  'mape': 0.457,
#  'method': 'seasonal_naive_prior_year',
#  'warning': 'Synthetic and partial-month data make this a planning demo, not a production forecast.'}

# %% [markdown]
# **So sánh phương pháp forecast** (backtest seasonal-naive vs moving-average):

# %% [markdown]
# **Vì sao bước này?**
# - Làm gì: Chạy và so sánh độ lỗi (MAE, MAPE) giữa 2 phương pháp dự báo cơ bản (Baseline Forecast): Seasonal-Naive (lấy cùng kỳ năm ngoái) và Moving-Average (lấy trung bình các tháng gần đây).
# - Vì sao: Do dữ liệu được sinh random nên dự báo chuỗi thời gian khó có quy luật dài hạn (trend/seasonality) ổn định. Chọn Seasonal-Naive vì tính đặc thù ngành hàng (nhu cầu F&B lặp lại theo mùa/tháng) thay vì dùng mô hình phức tạp (như ARIMA, Prophet) dễ bị overfit trên dữ liệu ngắn và nhiễu (vài tháng). Việc so sánh MAPE cho thấy dự báo bằng mọi giá trị lịch sử ở đây mang độ sai số rất lớn (>40%).
# - Kỹ thuật: Time Series Backtesting, Seasonal Naive Forecast, Mean Absolute Percentage Error (MAPE).
# - Bằng chứng dẫn tới: Dataset gồm chưa tới 3 năm (thiếu dữ liệu để fit mô hình chuỗi thời gian xịn), tháng cuối bị cắt cụt (partial month). So sánh MAPE chứng tỏ tín hiệu xu hướng trong dataset khá yếu.

# %%
pd.read_csv(PROJECT_ROOT / "reports" / "metrics" / "forecast_method_comparison.csv")
# Out:
#                       method  backtest_points     mae   mape
# 0  seasonal_naive_prior_year               19  12.211  0.457
# 1           moving_average_3               28  12.048  0.590

# %% [markdown]
# **Insight (forecast).** Cả hai phương pháp đều có MAPE cao trên dữ liệu
# nhỏ/synthetic + tháng partial; không phương pháp nào thắng rõ. Kết luận:
# forecast chỉ là **demo quy trình planning**, không cam kết độ chính xác
# sản xuất. Báo cáo phải nêu giới hạn này thay vì khoe MAPE.

# %%
hourly_staffing_plan(df).query("orders > 0").sort_values("scenario_orders_per_day", ascending=False)
# Out:
#     order_hour  orders  order_share  scenario_orders_per_day  \
# 19          19   328.0     0.326693                32.669323
# 18          18   312.0     0.310757                31.075697
# 20          20   306.0     0.304781                30.478088
# 13          13    43.0     0.042829                 4.282869
# 14          14     6.0     0.005976                 0.597610
# 17          17     4.0     0.003984                 0.398406
# 21          21     3.0     0.002988                 0.298805
# 12          12     2.0     0.001992                 0.199203
#
#     recommended_staff time_segment
# 19                  3       Dinner
# 18                  3       Dinner
# 20                  3       Dinner
# 13                  1        Lunch
# 14                  1        Lunch
# 17                  1       Dinner
# 21                  1         Late
# 12                  1        Lunch

# %%
Image(filename=str(PROJECT_ROOT / "reports" / "figures" / "monthly_demand_forecast.png"))

# %%
Image(filename=str(PROJECT_ROOT / "reports" / "figures" / "hourly_staffing_plan.png"))

# %% [markdown]
# ## 5. Trend by product and recommendation

# %%
type_trend, size_trend = monthly_product_trends(df)
type_trend.sort_values(["order_period", "orders"], ascending=[False, False]).head(20)
# Out:
#     order_period    pizza_type  orders  share_within_month
# 170      2026-07  Cheese Burst       2            0.285714
# 171      2026-07     Margarita       2            0.285714
# 169      2026-07   BBQ Chicken       1            0.142857
# 172      2026-07      Sicilian       1            0.142857
# 173      2026-07           Veg       1            0.142857
# 164      2026-06   BBQ Chicken       7            0.233333
# 165      2026-06  Cheese Burst       6            0.200000
# 166      2026-06     Margarita       6            0.200000
# 168      2026-06           Veg       6            0.200000
# 167      2026-06      Sicilian       5            0.166667
# 160      2026-05  Cheese Burst       7            0.225806
# 161      2026-05     Margarita       7            0.225806
# 159      2026-05   BBQ Chicken       6            0.193548
# 162      2026-05      Sicilian       6            0.193548
# 163      2026-05           Veg       5            0.161290
# 154      2026-04   BBQ Chicken       7            0.233333
# 155      2026-04  Cheese Burst       6            0.200000
# 156      2026-04     Margarita       6            0.200000
# 158      2026-04           Veg       6            0.200000
# 157      2026-04      Sicilian       5            0.166667

# %% [markdown]
# **Kiểm định xu hướng sở thích (Mann-Kendall)** — có trend thật về sau không?

# %% [markdown]
# **Vì sao bước này?**
# - Làm gì: Sử dụng phép thử phi tham số Mann-Kendall để kiểm định xem tỷ trọng từng phân khúc (ví dụ: share của Pizza Size Medium) có xu hướng tăng hay giảm thực sự theo thời gian hay không.
# - Vì sao: Thay vì nhìn biểu đồ lên xuống thất thường (vẽ bằng mắt thường dễ bị thiên lệch), Mann-Kendall trả lời chắc chắn bằng p-value rằng "sự lên xuống này là nhiễu ngẫu nhiên, hay đang có trend dài hạn?". Phép thử này miễn nhiễm với các ngoại lệ (outliers) hoặc dữ liệu không phân phối chuẩn.
# - Kỹ thuật: Mann-Kendall Trend Test (Non-parametric test).
# - Bằng chứng dẫn tới: Đa số các loại pizza/size báo cáo `trend = no_trend` (p-value >= 0.05), xác nhận bản chất dữ liệu không có trend, giải thích vì sao forecast có sai số cao.

# %%
pd.read_csv(PROJECT_ROOT / "reports" / "metrics" / "preference_trend_tests.csv")
# Out:
#      dimension       category  months     tau  p_value              trend
# 0   pizza_size       01_Small      20 -0.1368   0.4173           no_trend
# 1   pizza_size      02_Medium      31  0.3333   0.0089         increasing
# 2   pizza_size       03_Large      31 -0.1892   0.1392           no_trend
# 3   pizza_size          04_XL      31  0.3097   0.0151         increasing
# 4   pizza_type    BBQ Chicken       9 -0.0556   0.9170           no_trend
# 5   pizza_type   Cheese Burst      31  0.2430   0.0570           no_trend
# 6   pizza_type      Deep Dish       4 -0.6667   0.3082           no_trend
# 7   pizza_type    Gluten-Free      13  0.4359   0.0441         increasing
# 8   pizza_type      Margarita       9  0.3333   0.2515           no_trend
# 9   pizza_type        Non-Veg      21 -0.7048   0.0000         decreasing
# 10  pizza_type       Sicilian      17  0.5074   0.0051         increasing
# 11  pizza_type  Stuffed Crust       9 -0.1111   0.7545           no_trend
# 12  pizza_type   Thai Chicken       9  0.6111   0.0286         increasing
# 13  pizza_type     Thin Crust       1     NaN      NaN  insufficient_data
# 14  pizza_type            Veg      31 -0.2903   0.0228         decreasing
# 15  pizza_type          Vegan      20 -0.1211   0.4754           no_trend

# %% [markdown]
# **Insight (trend).** Hầu hết category có `trend = no_trend` (p ≥ 0.05):
# share size/type **không** có xu hướng tăng/giảm có ý nghĩa. Đây là câu
# trả lời trung thực cho "dự đoán trend về sau?": *forecast được về mặt cơ
# học, nhưng dữ liệu không cho thấy trend thực để dự báo* — đúng bản chất
# dữ liệu random.

# %%
recommendation_rules(df).head(20)
# Out:
#                                      rule_type  \
# 48  Most chosen restaurant for same pizza type
# 51  Most chosen restaurant for same pizza type
# 15       Top pizza type by restaurant and size
# 8        Top pizza type by restaurant and size
# 18       Top pizza type by restaurant and size
# 42            Preferred restaurant by location
# 17       Top pizza type by restaurant and size
# 7        Top pizza type by restaurant and size
# 37            Preferred restaurant by location
# 59                    Top size by time segment
# 41            Preferred restaurant by location
# 20            Preferred restaurant by location
# 40            Preferred restaurant by location
# 19       Top pizza type by restaurant and size
# 53  Most chosen restaurant for same pizza type
# 50  Most chosen restaurant for same pizza type
# 16       Top pizza type by restaurant and size
# 31            Preferred restaurant by location
# 12       Top pizza type by restaurant and size
# 9        Top pizza type by restaurant and size
#
#                                               context  \
# 48                             pizza_type=BBQ Chicken
# 51                               pizza_type=Margarita
# 15      restaurant_name=Papa John's, pizza_size=Small
# 8    restaurant_name=Little Caesars, pizza_size=Small
# 18        restaurant_name=Pizza Hut, pizza_size=Small
# 42                                 location=Omaha, NE
# 17       restaurant_name=Pizza Hut, pizza_size=Medium
# 7   restaurant_name=Little Caesars, pizza_size=Medium
# 37                            location=Louisville, KY
# 59                                 time_segment=Lunch
# 41                              location=New York, NY
# 20                           location=Albuquerque, NM
# 40                             location=Milwaukee, WI
# 19           restaurant_name=Pizza Hut, pizza_size=XL
# 53                                pizza_type=Sicilian
# 50                             pizza_type=Gluten-Free
# 16        restaurant_name=Pizza Hut, pizza_size=Large
# 31                               location=El Paso, TX
# 12    restaurant_name=Marco's Pizza, pizza_size=Small
# 9       restaurant_name=Little Caesars, pizza_size=XL
#
#                     recommendation  context_orders  matched_orders  confidence
# 48     restaurant_name=Papa John's              54              54    1.000000
# 51   restaurant_name=Marco's Pizza              54              54    1.000000
# 15                pizza_type=Vegan              47              47    1.000000
# 8                 pizza_type=Vegan              43              43    1.000000
# 18                pizza_type=Vegan              23              23    1.000000
# 42     restaurant_name=Papa John's              68              67    0.985294
# 17                  pizza_type=Veg              65              64    0.984615
# 7               pizza_type=Non-Veg              46              45    0.978261
# 37  restaurant_name=Little Caesars              69              67    0.971014
# 59               pizza_size=Medium              51              49    0.960784
# 41        restaurant_name=Domino's              21              20    0.952381
# 20        restaurant_name=Domino's              59              56    0.949153
# 40   restaurant_name=Marco's Pizza              71              67    0.943662
# 19         pizza_type=Cheese Burst              88              82    0.931818
# 53        restaurant_name=Domino's              64              59    0.921875
# 50     restaurant_name=Papa John's              41              37    0.902439
# 16              pizza_type=Non-Veg              18              16    0.888889
# 31     restaurant_name=Papa John's               9               8    0.888889
# 12                pizza_type=Vegan              17              15    0.882353
# 9          pizza_type=Cheese Burst             110              93    0.845455

# %%
Image(filename=str(PROJECT_ROOT / "reports" / "figures" / "preference_size_share_forecast.png"))

# %%
Image(filename=str(PROJECT_ROOT / "reports" / "figures" / "preference_type_share_forecast.png"))

# %% [markdown]
# ## 6. Insight → quyết định

# %%
pd.DataFrame([
    {
        "module": "Customer preference",
        "insight": "Medium và Non-Veg có order share cao nhất; một số combo type-size có delay rate cao.",
        "decision": "Dùng trong dashboard mix sản phẩm và rule recommendation, không dùng làm kết luận thị trường thật.",
    },
    {
        "module": "Demand forecast",
        "insight": "Seasonal-naive forecast có MAPE cao do dữ liệu nhỏ/synthetic và tháng partial.",
        "decision": "Chỉ dùng forecast như minh họa staffing/planning, không cam kết dự báo sản xuất.",
    },
    {
        "module": "Staffing",
        "insight": "Peak order hour là 19h trong kịch bản hiện tại.",
        "decision": "Tạo staffing scenario 100 đơn/ngày để minh họa phân bổ nhân sự.",
    },
    {
        "module": "Recommendation",
        "insight": "Rule dựa trên popularity/context dễ giải thích nhưng chưa cá nhân hóa.",
        "decision": "Dùng làm lớp gợi ý minh bạch trong DSS, không coi là recommender production.",
    },
])
# Out:
#                 module                                            insight  \
# 0  Customer preference  Medium và Non-Veg có order share cao nhất; một...
# 1      Demand forecast  Seasonal-naive forecast có MAPE cao do dữ liệu...
# 2             Staffing    Peak order hour là 19h trong kịch bản hiện tại.
# 3       Recommendation  Rule dựa trên popularity/context dễ giải thích...
#
#                                             decision
# 0  Dùng trong dashboard mix sản phẩm và rule reco...
# 1  Chỉ dùng forecast như minh họa staffing/planni...
# 2  Tạo staffing scenario 100 đơn/ngày để minh họa...
# 3  Dùng làm lớp gợi ý minh bạch trong DSS, không ...

# %% [markdown]
# ## 7. Xác nhận artifact
#
# CSV/figure business đã sinh **một lần** ở Bước 0 (`build_business_artifacts`).
# Cell dưới chỉ liệt kê, không tính lại.

# %%
import os
metrics = sorted(f for f in os.listdir(PROJECT_ROOT / "reports" / "metrics") if f.endswith((".csv", ".json")))
{"n_metric_files": len(metrics), "examples": metrics[:8]}
# Out:
# {'n_metric_files': 88,
#  'examples': ['association_rules.csv',
#   'baseline_dev_metrics.csv',
#   'baseline_test_metrics.csv',
#   'brand_ablation.csv',
#   'brand_delta_f2_bootstrap.csv',
#   'brand_homogeneity_tests.csv',
#   'business_analysis_summary.json',
#   'chain_aggregated_location_time.csv']}
