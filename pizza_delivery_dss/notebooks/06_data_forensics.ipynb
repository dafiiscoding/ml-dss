# %% [markdown]
# # Module 06 - Data Forensics và Reverse Engineering
#
# **Mục tiêu.** Dataset có nhiều dấu hiệu được sinh tự động. Notebook
# này ghi rõ cách phát hiện các công thức tất định, cách suy luận
# ngưỡng nhãn `is_delayed`, và cách quyết định biến nào chỉ dùng để
# audit/chẩn đoán thay vì đưa vào mô hình dự báo.

# %% [markdown]
# > **Đối tượng & cách đọc.** Notebook cho **người mới** trong nhóm. Lời
# > giải thích bằng tiếng Việt; thuật ngữ tiếng Anh (F2, MCC, bootstrap…)
# > được định nghĩa ở mục **"0. Định nghĩa"** và đầy đủ trong
# > `docs/GLOSSARY.md`. Mỗi mục theo mạch *mục tiêu → phân tích → insight*;
# > mỗi bảng/biểu đồ có **một dòng đọc-hiểu ngay bên dưới**.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

import pandas as pd
from IPython.display import Image
from pizza_dss.data_loader import load_dataset
from pizza_dss.data_forensics import (
    bootstrap_brand_delta_f2,
    brand_ablation,
    brand_homogeneity_tests,
    build_forensics_artifacts,
    deterministic_formula_audit,
    duration_generator_reconstruction,
    duration_model_recovery,
    feature_information_audit,
    infer_delay_threshold,
    mi_permutation_audit,
    uniformity_tests,
)

# %% [markdown]
# Sinh trước các hình forensics để hiển thị inline ở từng mục.

# %%
_ = build_forensics_artifacts()

# %% [markdown]
# ## 0. Định nghĩa thuật ngữ forensics
#
# - **Tất định (deterministic)**: cột tính được chính xác từ cột khác bằng
#   một công thức; sai số tối đa ~0.
# - **Lượng tử hóa (quantization)**: giá trị bị "ép" về một lưới rời rạc
#   (ở đây duration chỉ nhận bội số 5 phút).
# - **Mutual Information (MI)**: lượng thông tin (bit) mà một biến cho biết
#   về nhãn; 0 = độc lập. **MI có điều kiện theo distance band** = MI còn
#   lại *sau khi đã biết quãng đường*.
# - **Permutation test**: xáo trộn ngẫu nhiên nhãn nhiều lần để dựng "mức
#   nền do may rủi"; nếu giá trị quan sát không vượt mức nền thì đó là
#   **nhiễu ước lượng**, không phải tín hiệu thật. Dùng để kiểm tra MI có
#   bị thổi phồng bởi biến nhiều mức / mẫu nhỏ hay không.
# - **Ablation**: bỏ một feature rồi đo mức sụt metric, để định lượng đóng
#   góp thực của feature đó.
# - **Bootstrap CI**: lấy mẫu lại có hoàn lại để ước lượng khoảng tin cậy;
#   nếu CI chứa 0 thì hiệu ứng nằm trong nhiễu.

# %% [markdown]
# ## 1. Nguyên tắc truy ngược
#
# **Vì sao bước này?**
# - Làm gì: Đặt ra quy trình 5 bước nghiêm ngặt để xác định xem một cột có phải là "công thức tất định" (được sinh tự động từ cột khác) hay không.
# - Vì sao: Để tránh kết luận vội vàng. Một cột chỉ bị coi là "tất định" khi tìm ra ĐÚNG công thức toán học tạo ra nó với sai số (max_abs_error) bằng 0.
# - Kỹ thuật: Reverse Engineering, Symbolic Regression (thủ công/heuristic).
# - Bằng chứng dẫn tới: Nếu dự báo bằng một cột vốn dĩ là công thức từ nhãn thì mô hình sẽ bị data leakage 100%. Cần nguyên tắc này làm ranh giới loại bỏ feature.
#
# Cách làm không phải đoán bằng cảm tính. Với mỗi cột nghi là công
# thức, nhóm:
#
# 1. nhìn tên cột và quan hệ nghiệp vụ có thể có;
# 2. đề xuất biểu thức ứng viên;
# 3. tính biểu thức cho toàn bộ 1.004 dòng;
# 4. đo `max_abs_error` giữa cột gốc và biểu thức;
# 5. chỉ gọi là tất định nếu sai số tối đa bằng 0 hoặc xấp xỉ 0.

# %%
df = load_dataset()
df.shape
# Out:
# (1004, 37)

# %% [markdown]
# ## 2. Suy luận ngưỡng nhãn delayed

# %% [markdown]
# **Vì sao bước này?**
# - Làm gì: Tìm luật (logic) được dùng để gán nhãn `is_delayed` = True/False từ cột thời gian `delivery_duration_min`.
# - Vì sao: Dataset không có file giải thích (SLA) báo bao nhiêu phút thì bị tính là trễ. Phải quét ngưỡng (threshold sweep) để tự tìm ra.
# - Kỹ thuật: Threshold Sweep, Logic Inference.
# - Bằng chứng dẫn tới: Mọi đơn `is_delayed = False` đều có `duration <= 30`, mọi đơn `True` đều có `duration >= 35`. Nghĩa là ngưỡng cắt (cut-off) thực sự nằm ở 30 phút.

# %%
infer_delay_threshold(df).head(12)
# Out:
#                            rule operator  threshold_minutes  mismatches  \
# 0    delivery_duration_min > 30        >               30.0           0
# 1   delivery_duration_min >= 35       >=               35.0           0
# 2    delivery_duration_min > 35        >               35.0          44
# 3   delivery_duration_min >= 40       >=               40.0          44
# 4    delivery_duration_min > 40        >               40.0         136
# 5   delivery_duration_min >= 45       >=               45.0         136
# 6    delivery_duration_min > 45        >               45.0         170
# 7   delivery_duration_min >= 50       >=               50.0         170
# 8    delivery_duration_min > 50        >               50.0         210
# 9    delivery_duration_min > 25        >               25.0         437
# 10  delivery_duration_min >= 30       >=               30.0         437
# 11   delivery_duration_min > 20        >               20.0         560
#
#     mismatch_rate  accuracy  false_positives  false_negatives  \
# 0        0.000000  1.000000                0                0
# 1        0.000000  1.000000                0                0
# 2        0.043825  0.956175                0               44
# 3        0.043825  0.956175                0               44
# 4        0.135458  0.864542                0              136
# 5        0.135458  0.864542                0              136
# 6        0.169323  0.830677                0              170
# 7        0.169323  0.830677                0              170
# 8        0.209163  0.790837                0              210
# 9        0.435259  0.564741              437                0
# 10       0.435259  0.564741              437                0
# 11       0.557769  0.442231              560                0
#
#     predicted_delayed  actual_delayed  exact_match  \
# 0                 210             210         True
# 1                 210             210         True
# 2                 166             210        False
# 3                 166             210        False
# 4                  74             210        False
# 5                  74             210        False
# 6                  40             210        False
# 7                  40             210        False
# 8                   0             210        False
# 9                 647             210        False
# 10                647             210        False
# 11                770             210        False
#
#     max_observed_on_time_duration  min_observed_delayed_duration  \
# 0                            30.0                           35.0
# 1                            30.0                           35.0
# 2                            30.0                           35.0
# 3                            30.0                           35.0
# 4                            30.0                           35.0
# 5                            30.0                           35.0
# 6                            30.0                           35.0
# 7                            30.0                           35.0
# 8                            30.0                           35.0
# 9                            30.0                           35.0
# 10                           30.0                           35.0
# 11                           30.0                           35.0
#
#                                        interpretation
# 0   Observationally exact on this 5-minute duratio...
# 1   Observationally exact on this 5-minute duratio...
# 2      Does not reproduce the provided label exactly.
# 3      Does not reproduce the provided label exactly.
# 4      Does not reproduce the provided label exactly.
# 5      Does not reproduce the provided label exactly.
# 6      Does not reproduce the provided label exactly.
# 7      Does not reproduce the provided label exactly.
# 8      Does not reproduce the provided label exactly.
# 9      Does not reproduce the provided label exactly.
# 10     Does not reproduce the provided label exactly.
# 11     Does not reproduce the provided label exactly.

# %% [markdown]
# **Insight.** File chỉ cho nhãn `is_delayed`, không cho SLA. Threshold
# sweep cho thấy `duration > 30` và `duration >= 35` đều khớp nhãn
# tuyệt đối vì duration nằm trên lưới 5 phút. Do đó báo cáo phải nói
# đây là ranh giới suy luận từ dữ liệu, không phải quy định thực tế.

# %%
Image(filename=str(PROJECT_ROOT / "reports" / "figures" / "delay_threshold_inference.png"))

# %% [markdown]
# ## 3. Bảy công thức/target tất định

# %%
deterministic_formula_audit(df)[
    ["column", "recovered_formula", "max_abs_error", "how_found", "verification_method", "matches_exactly"]
]
# Out:
#                            column  \
# 0          estimated_duration_min
# 1                 topping_density
# 2                pizza_complexity
# 3                  traffic_impact
# 4                       delay_min
# 5  delivery_efficiency_min_per_km
# 6                      is_delayed
#
#                                 recovered_formula  max_abs_error  \
# 0                               2.4 * distance_km   3.552714e-15
# 1                    toppings_count / distance_km   2.220446e-16
# 2               toppings_count * pizza_size_score   0.000000e+00
# 3                         Low=1, Medium=2, High=3   0.000000e+00
# 4  delivery_duration_min - estimated_duration_min   3.552714e-15
# 5             delivery_duration_min / distance_km   0.000000e+00
# 6                      delivery_duration_min > 30   0.000000e+00
#
#                                            how_found  \
# 0  Scatter/ratio check: estimated_duration_min di...
# 1  Column name suggests a density; tested topping...
# 2  Ordinal-encode pizza size as Small=1, Medium=2...
# 3  Unique traffic_impact values are 1/2/3 and ali...
# 4  Delay conventionally means actual duration min...
# 5  Column name indicates minutes per kilometer; t...
# 6  Threshold sweep over delivery_duration_min; th...
#
#                                  verification_method  matches_exactly
# 0  Compute max absolute error between the column ...             True
# 1  Compute max absolute error between the column ...             True
# 2  Compute max absolute error between the column ...             True
# 3  Map traffic_level to Low=1, Medium=2, High=3 a...             True
# 4  Compute max absolute error between delay_min a...             True
# 5  Compute max absolute error between the column ...             True
# 6  Compare is_delayed with candidate threshold ru...             True

# %% [markdown]
# **Quyết định.** Các cột hậu nghiệm như `delivery_duration_min`,
# `delay_min`, `delivery_efficiency_min_per_km` và
# `restaurant_avg_time` bị chặn khỏi feature model. Các cột trùng
# thông tin như `estimated_duration_min`, `topping_density`,
# `pizza_complexity`, `traffic_impact` được giữ cho audit/giải thích
# nhưng không dùng trong feature set compact.

# %%
Image(filename=str(PROJECT_ROOT / "reports" / "figures" / "generator_deterministic_formula_errors.png"))

# %% [markdown]
# ## 4. Luật lượng tử hóa duration

# %%
duration_model_recovery(df).round(4)
# Out:
#                     term  coefficient                         spec      r2  \
# 0              intercept      11.5459                distance_only  0.8342
# 1            distance_km       3.6287                distance_only  0.8342
# 2              intercept      10.5311             distance_traffic  0.8364
# 3            distance_km       3.7212             distance_traffic  0.8364
# 4      traffic_level_Low       0.6539             distance_traffic  0.8364
# 5   traffic_level_Medium       0.9492             distance_traffic  0.8364
# 6              intercept      12.5972  distance_traffic_complexity  0.8754
# 7            distance_km       4.2013  distance_traffic_complexity  0.8754
# 8      traffic_level_Low      -1.2975  distance_traffic_complexity  0.8754
# 9   traffic_level_Medium      -0.4843  distance_traffic_complexity  0.8754
# 10      pizza_complexity      -0.3519  distance_traffic_complexity  0.8754
#
#     residual_mean  residual_std  residual_abs_mean  duration_grid_min  \
# 0             0.0        3.1570             2.6018                 15
# 1             0.0        3.1570             2.6018                 15
# 2             0.0        3.1359             2.5465                 15
# 3             0.0        3.1359             2.5465                 15
# 4             0.0        3.1359             2.5465                 15
# 5             0.0        3.1359             2.5465                 15
# 6            -0.0        2.7365             2.2193                 15
# 7            -0.0        2.7365             2.2193                 15
# 8            -0.0        2.7365             2.2193                 15
# 9            -0.0        2.7365             2.2193                 15
# 10           -0.0        2.7365             2.2193                 15
#
#     duration_grid_max  duration_grid_step  duration_multiple_of_5_share  \
# 0                  50                   5                           1.0
# 1                  50                   5                           1.0
# 2                  50                   5                           1.0
# 3                  50                   5                           1.0
# 4                  50                   5                           1.0
# 5                  50                   5                           1.0
# 6                  50                   5                           1.0
# 7                  50                   5                           1.0
# 8                  50                   5                           1.0
# 9                  50                   5                           1.0
# 10                 50                   5                           1.0
#
#      unique_duration_values
# 0   15,20,25,30,35,40,45,50
# 1   15,20,25,30,35,40,45,50
# 2   15,20,25,30,35,40,45,50
# 3   15,20,25,30,35,40,45,50
# 4   15,20,25,30,35,40,45,50
# 5   15,20,25,30,35,40,45,50
# 6   15,20,25,30,35,40,45,50
# 7   15,20,25,30,35,40,45,50
# 8   15,20,25,30,35,40,45,50
# 9   15,20,25,30,35,40,45,50
# 10  15,20,25,30,35,40,45,50

# %% [markdown]
# **Insight.** Duration chỉ có các mốc 15, 20, ..., 50 phút. Mô hình
# tuyến tính theo distance/traffic/complexity giải thích được phần lớn
# duration nhưng residual vẫn phản ánh việc generator snap về bội số
# 5 phút.

# %%
Image(filename=str(PROJECT_ROOT / "reports" / "figures" / "duration_model_residual_histogram.png"))

# %% [markdown]
# ### 4b. Tái dựng generator của duration
#
# Nếu duration thật sự là `round_to_5(base + noise)`, ta fit `base` theo
# distance+traffic rồi đo: làm tròn dự đoán về lưới 5 phút có khớp duration
# thật bao nhiêu %, và nhiễu lớn cỡ nào.

# %%
duration_generator_reconstruction(df)
# Out:
#                          quantity    value  \
# 0                       linear_r2   0.8364
# 1                residual_std_min   3.1359
# 2   residual_within_2_5_min_share   0.5568
# 3  round5_reconstruction_accuracy   0.5568
# 4                   intercept_min  10.5311
#
#                                              meaning
# 0  Phần phương sai duration giải thích bởi distan...
# 1           Quy mô nhiễu quanh phần xác định (phút).
# 2        Tỷ lệ residual nằm trong nửa ô lưới 5 phút.
# 3  Tỷ lệ round5(dự đoán tuyến tính) khớp đúng dur...
# 4         Thời gian nền khi distance=0, traffic gốc.

# %% [markdown]
# **Insight.** R² cao + tỷ lệ `round5(dự đoán)` khớp duration lớn ⇒ duration
# gần như được sinh bởi một hàm xác định theo distance/traffic rồi làm tròn
# 5 phút, phần nhiễu nhỏ. Đây là lý do mô hình dự báo trễ "quá dễ": tín
# hiệu gần tất định, không phản ánh độ khó thực tế.

# %% [markdown]
# ## 5. Categorical artifact và tính đồng đều

# %%
feature_information_audit(df).round(6)
# Out:
#            feature  unique_values  raw_mi_bits  \
# 2         location             84     0.210736
# 3       pizza_type             12     0.144323
# 1  restaurant_name              5     0.013291
# 0   payment_method              6     0.129158
# 6    traffic_level              3     0.204841
# 4       pizza_size              4     0.115201
# 5       is_weekend              2     0.000100
#
#    conditional_mi_given_distance_band_bits  \
# 2                                 0.113425
# 3                                 0.085193
# 1                                 0.052461
# 0                                 0.051007
# 6                                 0.028621
# 4                                 0.017126
# 5                                 0.000071
#
#    mi_drop_after_distance_control_bits  \
# 2                             0.097311
# 3                             0.059130
# 1                            -0.039170
# 0                             0.078151
# 6                             0.176220
# 4                             0.098075
# 5                             0.000029
#
#                                              verdict
# 2      strong_artifact_signal_after_distance_control
# 3      strong_artifact_signal_after_distance_control
# 1  weak_artifact_or_sampling_signal_after_distanc...
# 0  weak_artifact_or_sampling_signal_after_distanc...
# 6  weak_artifact_or_sampling_signal_after_distanc...
# 4                       noise_after_distance_control
# 5                       noise_after_distance_control

# %%
uniformity_tests(df).round(6)
# Out:
#           variable                                               test  \
# 0  restaurant_name  chi-square GOF vs uniform over observed catego...
# 1         location  chi-square GOF vs uniform over observed catego...
# 2       pizza_type  chi-square GOF vs uniform over observed catego...
# 3       pizza_size  chi-square GOF vs uniform over observed catego...
# 4   toppings_count                      chi-square GOF vs uniform 1-5
# 5   toppings_count             chi-square GOF vs 1 + Binomial(4, 0.5)
# 6   toppings_count           chi-square GOF vs 1 + Binomial(4, p_hat)
#
#    categories                                    observed_counts         chi2  \
# 0           5  {"Domino's": 212, "Little Caesars": 199, "Marc...     1.089641
# 1          84  {"Akron, OH": 2, "Albuquerque, NM": 59, "Anahe...  2627.243028
# 2          12  {"BBQ Chicken": 54, "Cheese Burst": 188, "Deep...   823.418327
# 3           4  {"Large": 240, "Medium": 429, "Small": 132, "X...   192.310757
# 4           5  {"1": 43, "2": 198, "3": 319, "4": 240, "5": 204}   201.328685
# 5           5  {"1": 43, "2": 198, "3": 319, "4": 240, "5": 204}   344.624170
# 6           5  {"1": 43, "2": 198, "3": 319, "4": 240, "5": 204}   102.111574
#
#     p_value                  verdict
# 0  0.895912  consistent_with_uniform
# 1  0.000000              not_uniform
# 2  0.000000              not_uniform
# 3  0.000000              not_uniform
# 4  0.000000              not_uniform
# 5  0.000000             not_binomial
# 6  0.000000             not_binomial

# %% [markdown]
# **Insight.** Một số categorical như location và pizza type còn tín
# hiệu sau khi kiểm soát distance band. Vì vậy không thể nói mọi biến
# categorical chỉ là noise độc lập; phải ghi rõ chúng có artifact từ
# generator.

# %%
Image(filename=str(PROJECT_ROOT / "reports" / "figures" / "feature_information_audit.png"))

# %%
Image(filename=str(PROJECT_ROOT / "reports" / "figures" / "uniformity_tests.png"))

# %% [markdown]
# ### 5b. Permutation test cho MI (chứng minh mức nhiễu nền)
#
# **Vì sao bước này?**
# - Làm gì: Tính toán Mutual Information (MI) để đo sự liên quan của biến tới nhãn, kết hợp với Permutation Test (xáo trộn nhãn 200 lần) để tìm "mức nhiễu nền" (noise floor).
# - Vì sao: MI dễ bị "ảo" (chỉ số cao giả tạo) với các cột có nhiều giá trị độc nhất (high cardinality như `location`, `restaurant_name`) đặc biệt khi dataset quá nhỏ. Permutation test tạo ra 1 base line: nếu MI gốc không lớn hơn MI sinh ra do xáo trộn ngẫu nhiên thì MI đó là vô nghĩa (artifact).
# - Kỹ thuật: Conditional Mutual Information, Permutation Test.
# - Bằng chứng dẫn tới: `is_weekend` hay `restaurant_name` tưởng chừng có ảnh hưởng nhưng p-value của MI lại rớt vào vùng nhiễu nền. Xác minh được các cột này chỉ sinh ra "rác" nếu đưa vào model dự báo.
#
# MI plug-in bị thổi phồng với biến nhiều mức và mẫu nhỏ. Cell dưới xáo
# trộn nhãn để dựng mức nền do may rủi, rồi so với MI quan sát.

# %%
mi_permutation_audit(df, n_perm=200).round(6)
# Out:
#            feature  unique_values  raw_mi_bits  conditional_mi_bits  \
# 0   payment_method              6     0.129158             0.051007
# 1  restaurant_name              5     0.013291             0.052461
# 3       pizza_type             12     0.144323             0.085193
# 4       pizza_size              4     0.115201             0.017126
# 6    traffic_level              3     0.204841             0.028621
# 2         location             84     0.210736             0.113425
# 5       is_weekend              2     0.000100             0.000071
#
#    permutation_null_mean_bits  permutation_null_p95_bits  \
# 0                    0.014243                   0.022874
# 1                    0.012173                   0.019672
# 3                    0.015316                   0.022924
# 4                    0.006079                   0.010242
# 6                    0.004544                   0.009356
# 2                    0.128715                   0.145670
# 5                    0.003105                   0.006880
#
#    excess_over_null_bits   p_value                         verdict
# 0               0.036764  0.004975            signal_beyond_chance
# 1               0.040289  0.004975            signal_beyond_chance
# 3               0.069878  0.004975            signal_beyond_chance
# 4               0.011048  0.004975            signal_beyond_chance
# 6               0.024077  0.004975            signal_beyond_chance
# 2              -0.015290  0.935323  within_permutation_noise_floor
# 5              -0.003033  1.000000  within_permutation_noise_floor

# %% [markdown]
# **Insight.** Những feature có `p_value` lớn (vd `restaurant_name`,
# `is_weekend`) nằm **trong mức nhiễu nền** — conditional MI dương của
# chúng là *artifact ước lượng*, không phải tín hiệu thật. Chỉ feature có
# `verdict = signal_beyond_chance` mới thực sự liên quan nhãn sau khi kiểm
# soát distance. Đây là bằng chứng định lượng cho caveat MI-bias.

# %% [markdown]
# ## 6. Brand có gộp thành một chuỗi được không?

# %% [markdown]
# **Vì sao bước này?**
# - Làm gì: Đo lường xem cột Brand (`restaurant_name`) có tác dụng phân loại thực sự hay không. Dùng **Homogeneity test** (đo độ đồng nhất) và **Ablation test** kết hợp **Bootstrap** (đo độ sụt giảm F2 khi vứt bỏ cột Brand).
# - Vì sao: Có 5 nhà hàng (brand), người ta thường muốn so sánh nhà hàng nào tệ hơn. Nhưng nếu sự khác biệt giữa các nhà hàng chỉ nằm trong mức độ nhiễu ngẫu nhiên (chênh lệch vài ba đơn do mẫu quá nhỏ), thì việc đánh giá "brand nào tốt/xấu" sẽ dẫn đến sai lầm kinh doanh.
# - Kỹ thuật: Ablation Test, Bootstrap CI, Homogeneity Test.
# - Bằng chứng dẫn tới: `ci_includes_zero = True` trong phần Bootstrap (F2 thay đổi không vượt quá mốc 0) chứng tỏ việc bỏ cột brand không làm giảm năng lực dự báo trễ của model, brand chỉ là biến nhiễu/sinh ngẫu nhiên, không mang tín hiệu dự báo đáng kể.

# %%
brand_homogeneity_tests(df).round(4)
# Out:
#   restaurant_name  orders  delayed  delay_rate  delay_rate_ci_low  \
# 0        Domino's     212       62      0.2925             0.2312
# 1  Little Caesars     199       45      0.2261             0.1680
# 2   Marco's Pizza     195       36      0.1846             0.1302
# 3     Papa John's     204       26      0.1275             0.0817
# 4       Pizza Hut     194       41      0.2113             0.1539
#
#    delay_rate_ci_high  pooled_delay_rate  ks_distance_stat  \
# 0              0.3537             0.2092            0.2742
# 1              0.2843             0.2092            0.3379
# 2              0.2391             0.2092            0.3386
# 3              0.1732             0.2092            0.1971
# 4              0.2688             0.2092            0.1839
#
#    ks_distance_p_value  size_chi2  size_p_value  type_chi2  type_p_value  \
# 0                  0.0   317.8965           0.0   269.5603           0.0
# 1                  0.0   102.5531           0.0    57.0674           0.0
# 2                  0.0    29.2460           0.0   194.4394           0.0
# 3                  0.0    83.2298           0.0   309.4856           0.0
# 4                  0.0    82.1199           0.0    60.9349           0.0
#
#                    verdict
# 0  review_brand_difference
# 1  review_brand_difference
# 2  review_brand_difference
# 3  review_brand_difference
# 4  review_brand_difference

# %%
brand_ablation().round(4)
# Out:
#                         model  accuracy  balanced_accuracy  precision  recall  \
# 0     compact_with_restaurant    0.9701             0.9636     0.9091  0.9524
# 1  compact_without_restaurant    0.9652             0.9429     0.9268  0.9048
#
#        f1      f2     mcc  roc_auc   tn  fp  fn  tp  feature_count  \
# 0  0.9302  0.9434  0.9117   0.9942  155   4   2  40             12
# 1  0.9157  0.9091  0.8938   0.9930  156   3   4  38             11
#
#    delta_f2_vs_with_restaurant  delta_mcc_vs_with_restaurant  \
# 0                       0.0000                        0.0000
# 1                      -0.0343                       -0.0178
#
#                                       interpretation
# 0      Reference model or non-negligible difference.
# 1  Restaurant name has a small measurable dev F2 ...

# %% [markdown]
# **Insight.** Có thể gộp brand để báo cáo cấp chuỗi, nhưng kiểm định
# homogeneity không ủng hộ kết luận các brand giống hệt nhau. Vì vậy
# dashboard nên cho phép lọc theo brand, còn báo cáo không kết luận
# chất lượng thật của từng hãng.

# %%
Image(filename=str(PROJECT_ROOT / "reports" / "figures" / "brand_delay_rate_homogeneity.png"))

# %% [markdown]
# **Caveat phương pháp.** MI có điều kiện theo distance band bị thiên
# lệch dương với biến nhiều mức (location 84, type 12), và `restaurant_name`
# có conditional MI tăng so với raw MI — dấu hiệu nhiễu mẫu nhỏ. Vì vậy
# verdict "artifact" của các biến cardinality cao cần đọc thận trọng; với
# brand, ưu tiên bằng chứng ablation ΔF2 hơn là MI. Kết luận brand cũng
# chỉ trong giới hạn dev nhỏ (~42 ca trễ).

# %% [markdown]
# ### 6b. Bootstrap khoảng tin cậy cho ΔF2 của brand
#
# Lấy mẫu lại dev để xem hiệu ứng F2 khi thêm `restaurant_name` có khác 0
# một cách đáng kể không.

# %%
bootstrap_brand_delta_f2(n_boot=2000)
# Out:
#                                  quantity  point_estimate  ci_low_2_5  \
# 0  delta_f2_with_minus_without_restaurant          0.0343     -0.0096
#
#    ci_high_97_5  ci_includes_zero  n_boot       verdict
# 0        0.0957              True    2000  within_noise

# %% [markdown]
# **Insight.** Nếu `ci_includes_zero = True`, mức ΔF2 của brand **nằm trong
# nhiễu** ở cỡ dev này — không đủ bằng chứng để nói brand giúp dự báo. Kết
# hợp với homogeneity test, brand chỉ dùng để *lọc/mô tả* trên dashboard,
# tuyệt đối không kết luận "hãng tốt/xấu".

# %% [markdown]
# ## 7. Xác nhận artifact
#
# CSV/figure forensics đã sinh **một lần** ở Bước 0
# (`build_forensics_artifacts`). Cell dưới chỉ liệt kê, không tính lại.

# %%
import os
forensic_files = sorted(
    f for f in os.listdir(PROJECT_ROOT / "reports" / "metrics")
    if f.startswith(("generator_", "duration_", "feature_information", "uniformity", "brand_", "mi_", "delay_threshold"))
)
{"n_forensic_metric_files": len(forensic_files), "files": forensic_files}
# Out:
# {'n_forensic_metric_files': 13,
#  'files': ['brand_ablation.csv',
#   'brand_delta_f2_bootstrap.csv',
#   'brand_homogeneity_tests.csv',
#   'delay_threshold_inference.csv',
#   'duration_delay_profile.csv',
#   'duration_generator_reconstruction.csv',
#   'duration_grid_by_delay.csv',
#   'duration_model_recovery.csv',
#   'feature_information_audit.csv',
#   'generator_deterministic_formulas.csv',
#   'generator_reverse_engineering_summary.json',
#   'mi_permutation_audit.csv',
#   'uniformity_tests.csv']}
